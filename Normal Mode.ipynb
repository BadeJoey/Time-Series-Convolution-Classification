# %% [markdown]
# # Klassifizierer Test
#
# Setup Imports

# %%
import tensorflow as tf
from tensorflow import keras
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import pydot
import json
import logging

# %% [markdown]
# Erstellt ein Log File in dem alle Runs mit Hyperparametern und Zeit gespeichert werden. Somit geht keine Run verloren.

# %%
log = logging.getLogger(__name__)
log.setLevel(logging.DEBUG)
formatter = logging.Formatter(fmt="%(asctime)s %(levelname)s: %(message)s", 
                          datefmt="%Y-%m-%d - %H:%M:%S")
fh = logging.FileHandler("Classification_Run.log", "a")
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)
log.addHandler(fh)

# %% [markdown]
# ### Eine JSON Datei mit den Hyperparametern schreiben

# %%
# data ist in diesem Fall ein Dictionary
def write_JSON_file(path, file_name, data):
    file_path = './' + path + '/' + file_name + '.json'
    with open(file_path, 'w') as fp:
        json.dump(data, fp)

# %% [markdown]
# ## Auslesen der Daten
# Man nimmt die Daten von der RootUrl und slicet alle Labels __(y)__, sodass von jedem Eintrag der erste genommen wird.
# Die Daten __(x)__ beinhalten jeden Wert außer den ersten.
#
# Es wird zwischen Train- und Test-Set unterschieden.

# %%
def read_ucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)

root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = read_ucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = read_ucr(root_url + "FordA_TEST.tsv")
print(y_train.shape)
x_train.shape
# Out:
# (3601,)
# (3601, 500)

# %% [markdown]
# ## Visualisieren der Daten
# Als erstes finden wir heraus, wie viele verschiedene Klassen es gibt, in dem wir die Labels nach einzigartigen Labeln filtern.
# Danach Filtern wir die Klassen einzeln und plotten sie auf einen Graphen zusammen.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %% [markdown]
# ## Standartisieren der Daten
# Die Daten sind Z-Normalisiert. Jedes Sample hat einen Mittelwert von 0 und eine Standardabweichung von 1.
#
# Mit einem Reshape verwandeln wir die Univariate Time Series in eine MultiVariate.

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# Da wir später __sparse_categorical_crossentropy__ benutzen müssen wir die Anzahl der möglichen Klassen kennen

# %%
num_classes = len(np.unique(y_train))

# %% [markdown]
# Hier werden alle Werte geshufflet als Vorbereitung, um später ein gutes Validation-Set zubekommen

# %%
idx = np.random.permutation(len(x_train))

x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Alle Labels mit dem Wert __-1__ auf __0__ mappen -> keine negativen Ergebnisse

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# # Hyperparameter definieren

# %% [markdown]
# ### Import von Hyperparametern durch JSON

# %%
def load_JSON(path):
    with open(path) as json_file:
        daten = json.load(json_file)
        return daten
    
def load_hyperparameter(dictionary, path="./hyperparameter.json"):
    daten = load_JSON(path)
    for key, value in daten.items():
        dictionary[key] = value

# %% [markdown]
# Hier werden alle Hyperparameter definiert, sodass man sie leicht ändern kann

# %%
hyper_p = {
            "epochs" : 500,

            "batch_size" : 32,

            "filter_size" : 64,

            "kernel_size" : 3,
    
            "activation_function" : "relu",

            "optimizer" : "Adam",
    
            "learning_rate" : 0.001,

            "loss_function" : "sparse_categorical_crossentropy"
            }


callbacks = [
                keras.callbacks.ModelCheckpoint(
                    "best_model.h5", save_best_only=True, monitor="val_loss"
                ),
                keras.callbacks.ReduceLROnPlateau(
                    monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
                ),
                keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
            ]

metrics = ["sparse_categorical_accuracy"]

# %% [markdown]
# ### Einlesen der Hyperparameter durch JSON
# Wenn man eine JSON Datei importieren möchte, kann man diesen Befehl benutzen, der zur Zeit auskommentiert ist.
# Standardmäßig liegt er auf dem Pfad (`./hyperparameter.json`) wo die, aktuell besten, Hyperparameter abgelegt sind.
#
# Man kann aber einfach einen eigenen Pfad angeben => __load_JSON(dictionary,__ `./eigener/pfad/mit/parameter.json`__)__
#
# Wenn man aus einer zweiten Quelle Parameter lädt wird trotzdem auf der Standardstelle die besten Parameter gespeichert. Somit kann man neue Konfigurationen ausprobieren ohne die besten Konfigurationen zu überschreiben und speichert trotzdem die beste Konfiguration ab.
# <br>
# <br>
# <font color=red>__Achtung! Zur Verwendung bitte den Cell Type von "RawNB" zu "Code" wechseln__<font>

# %% [raw]
# try:
#     load_hyperparameter(hyper_p)                           # mit standart Pfad
#     # load_hyperparameter(hyper_p, "./folder/data.json")   # mit eigenen Pfad
# except FileNotFoundError:
#     logging.warning('Die Datei die Versucht wurde zu laden existiert nicht.')
#     print("Die Datei existiert nicht.")

# %% [markdown]
# # Normales Modell mit einzelnen Runs (Normal Mode)

# %% [markdown]
# ## Ein Modell bauen
# Wir bauen hier ein dense verbundenes __Convolutional Neural Network__

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)
    
    conv1 = keras.layers.Conv1D(filters=hyper_p["filter_size"], kernel_size=hyper_p["kernel_size"], padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.Activation(activation=hyper_p["activation_function"])(conv1)

    conv2 = keras.layers.Conv1D(filters=hyper_p["filter_size"], kernel_size=hyper_p["kernel_size"], padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.Activation(activation=hyper_p["activation_function"])(conv2)

    conv3 = keras.layers.Conv1D(filters=hyper_p["filter_size"], kernel_size=hyper_p["kernel_size"], padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.Activation(activation=hyper_p["activation_function"])(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Das Modell trainieren
# Hier werden verschiedene Callbacks angegeben
# - Das beste Modell speichern
# - Die Learing-Rate reduzieren, wenn ein Plateau erreicht wird
# - Frühzeitig stoppen, wenn keine Verbesserung mehr Eintritt

# %%
# Da man in der JSON nur einen String hat und keine Object, wird hier der folgende String zusammen gesetzt um einen 
# Optimizer zu definieren und die Learning_Rate zu setzen

# Diese Funktion sollte keinen Nutzern verfügbar gemacht werden aufgrund von Code Injection

# Beispiel: opti = keras.optimizers.Adam(learning_rate=0.0001)
str_opti = "opti = keras.optimizers." + hyper_p["optimizer"] + "(learning_rate=" + str(hyper_p["learning_rate"]) + ")"
exec(str_opti)


model.compile(
    optimizer=opti,
    loss=hyper_p["loss_function"],
    metrics=metrics,
)

history = model.fit(
    x_train,
    y_train,
    batch_size=hyper_p["batch_size"],
    epochs=hyper_p["epochs"],
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Train on 2880 samples, validate on 721 samples
# Epoch 1/500
# 2880/2880 [==============================] - 2s 798us/sample - loss: 0.5713 - sparse_categorical_accuracy: 0.7035 - val_loss: 0.7837 - val_sparse_categorical_accuracy: 0.4840
# Epoch 2/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.4703 - sparse_categorical_accuracy: 0.7663 - val_loss: 0.7520 - val_sparse_categorical_accuracy: 0.4840
# Epoch 3/500
# 2880/2880 [==============================] - 1s 177us/sample - loss: 0.4317 - sparse_categorical_accuracy: 0.7872 - val_loss: 0.7078 - val_sparse_categorical_accuracy: 0.5021
# Epoch 4/500
# 2880/2880 [==============================] - 0s 172us/sample - loss: 0.4273 - sparse_categorical_accuracy: 0.7833 - val_loss: 0.5852 - val_sparse_categorical_accuracy: 0.7060
# Epoch 5/500
# 2880/2880 [==============================] - 0s 173us/sample - loss: 0.4127 - sparse_categorical_accuracy: 0.7962 - val_loss: 0.8078 - val_sparse_categorical_accuracy: 0.5312
# Epoch 6/500
# 2880/2880 [==============================] - 1s 179us/sample - loss: 0.3997 - sparse_categorical_accuracy: 0.8024 - val_loss: 0.4079 - val_sparse_categorical_accuracy: 0.8391
# Epoch 7/500
# 2880/2880 [==============================] - 1s 178us/sample - loss: 0.3962 - sparse_categorical_accuracy: 0.8038 - val_loss: 0.3966 - val_sparse_categorical_accuracy: 0.8072
# Epoch 8/500
# 2880/2880 [==============================] - 1s 176us/sample - loss: 0.3796 - sparse_categorical_accuracy: 0.8177 - val_loss: 0.4828 - val_sparse_categorical_accuracy: 0.7268
# Epoch 9/500
# 2880/2880 [==============================] - 0s 173us/sample - loss: 0.3843 - sparse_categorical_accuracy: 0.8167 - val_loss: 0.3687 - val_sparse_categorical_accuracy: 0.8058
# Epoch 10/500
# 2880/2880 [==============================] - 0s 172us/sample - loss: 0.3783 - sparse_categorical_accuracy: 0.8153 - val_loss: 0.4039 - val_sparse_categorical_accuracy: 0.7781
# Epoch 11/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.3672 - sparse_categorical_accuracy: 0.8274 - val_loss: 0.3737 - val_sparse_categorical_accuracy: 0.8169
# Epoch 12/500
# 2880/2880 [==============================] - 0s 172us/sample - loss: 0.3617 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.3337 - val_sparse_categorical_accuracy: 0.8474
# Epoch 13/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.3548 - sparse_categorical_accuracy: 0.8365 - val_loss: 0.3682 - val_sparse_categorical_accuracy: 0.7933
# Epoch 14/500
# 2880/2880 [==============================] - 0s 172us/sample - loss: 0.3602 - sparse_categorical_accuracy: 0.8316 - val_loss: 0.3310 - val_sparse_categorical_accuracy: 0.8419
# Epoch 15/500
# 2880/2880 [==============================] - 1s 181us/sample - loss: 0.3512 - sparse_categorical_accuracy: 0.8396 - val_loss: 0.3206 - val_sparse_categorical_accuracy: 0.8558
# Epoch 16/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.3551 - sparse_categorical_accuracy: 0.8288 - val_loss: 0.3639 - val_sparse_categorical_accuracy: 0.8336
# Epoch 17/500
# 2880/2880 [==============================] - 1s 199us/sample - loss: 0.3509 - sparse_categorical_accuracy: 0.8396 - val_loss: 0.3168 - val_sparse_categorical_accuracy: 0.8669
# Epoch 18/500
# 2880/2880 [==============================] - 1s 177us/sample - loss: 0.3256 - sparse_categorical_accuracy: 0.8521 - val_loss: 0.3942 - val_sparse_categorical_accuracy: 0.7601
# Epoch 19/500
# 2880/2880 [==============================] - 1s 184us/sample - loss: 0.3272 - sparse_categorical_accuracy: 0.8562 - val_loss: 0.3164 - val_sparse_categorical_accuracy: 0.8558
# Epoch 20/500
# 2880/2880 [==============================] - 1s 176us/sample - loss: 0.3230 - sparse_categorical_accuracy: 0.8503 - val_loss: 0.3118 - val_sparse_categorical_accuracy: 0.8613
# Epoch 21/500
# 2880/2880 [==============================] - 1s 181us/sample - loss: 0.3222 - sparse_categorical_accuracy: 0.8507 - val_loss: 0.3119 - val_sparse_categorical_accuracy: 0.8585
# Epoch 22/500
# 2880/2880 [==============================] - 1s 190us/sample - loss: 0.3148 - sparse_categorical_accuracy: 0.8674 - val_loss: 0.2786 - val_sparse_categorical_accuracy: 0.8793
# Epoch 23/500
# 2880/2880 [==============================] - 1s 175us/sample - loss: 0.3091 - sparse_categorical_accuracy: 0.8726 - val_loss: 0.2964 - val_sparse_categorical_accuracy: 0.8821
# Epoch 24/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.3101 - sparse_categorical_accuracy: 0.8632 - val_loss: 0.3009 - val_sparse_categorical_accuracy: 0.8793
# Epoch 25/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.3013 - sparse_categorical_accuracy: 0.8743 - val_loss: 0.5656 - val_sparse_categorical_accuracy: 0.7032
# Epoch 26/500
# 2880/2880 [==============================] - 1s 186us/sample - loss: 0.2988 - sparse_categorical_accuracy: 0.8726 - val_loss: 0.2729 - val_sparse_categorical_accuracy: 0.8821
# Epoch 27/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.2966 - sparse_categorical_accuracy: 0.8785 - val_loss: 0.4619 - val_sparse_categorical_accuracy: 0.7323
# Epoch 28/500
# 2880/2880 [==============================] - 0s 171us/sample - loss: 0.2897 - sparse_categorical_accuracy: 0.8767 - val_loss: 0.2966 - val_sparse_categorical_accuracy: 0.8571
# Epoch 29/500
# 2880/2880 [==============================] - 1s 179us/sample - loss: 0.2902 - sparse_categorical_accuracy: 0.8778 - val_loss: 0.3878 - val_sparse_categorical_accuracy: 0.7920
# Epoch 30/500
# 2880/2880 [==============================] - 0s 169us/sample - loss: 0.2896 - sparse_categorical_accuracy: 0.8774 - val_loss: 0.3580 - val_sparse_categorical_accuracy: 0.8225
# Epoch 31/500
# 2880/2880 [==============================] - 1s 197us/sample - loss: 0.3054 - sparse_categorical_accuracy: 0.8729 - val_loss: 0.2719 - val_sparse_categorical_accuracy: 0.8752
# Epoch 32/500
# 2880/2880 [==============================] - 1s 177us/sample - loss: 0.2836 - sparse_categorical_accuracy: 0.8781 - val_loss: 0.2970 - val_sparse_categorical_accuracy: 0.8558
# Epoch 33/500
# 2880/2880 [==============================] - 1s 184us/sample - loss: 0.2671 - sparse_categorical_accuracy: 0.8917 - val_loss: 0.2673 - val_sparse_categorical_accuracy: 0.8918
# Epoch 34/500
# 2880/2880 [==============================] - 1s 197us/sample - loss: 0.2726 - sparse_categorical_accuracy: 0.8809 - val_loss: 0.2473 - val_sparse_categorical_accuracy: 0.9001
# Epoch 35/500
# 2880/2880 [==============================] - 1s 176us/sample - loss: 0.2857 - sparse_categorical_accuracy: 0.8740 - val_loss: 0.2661 - val_sparse_categorical_accuracy: 0.8793
# Epoch 36/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.2617 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.2717 - val_sparse_categorical_accuracy: 0.8738
# Epoch 37/500
# 2880/2880 [==============================] - 1s 185us/sample - loss: 0.2575 - sparse_categorical_accuracy: 0.8927 - val_loss: 0.4326 - val_sparse_categorical_accuracy: 0.7670
# Epoch 38/500
# 2880/2880 [==============================] - 1s 211us/sample - loss: 0.2636 - sparse_categorical_accuracy: 0.8917 - val_loss: 0.2730 - val_sparse_categorical_accuracy: 0.8738
# Epoch 39/500
# 2880/2880 [==============================] - ETA: 0s - loss: 0.2458 - sparse_categorical_accuracy: 0.905 - 1s 180us/sample - loss: 0.2541 - sparse_categorical_accuracy: 0.9007 - val_loss: 0.2389 - val_sparse_categorical_accuracy: 0.9057
# Epoch 40/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.2550 - sparse_categorical_accuracy: 0.8903 - val_loss: 0.2618 - val_sparse_categorical_accuracy: 0.8835
# Epoch 41/500
# 2880/2880 [==============================] - 0s 159us/sample - loss: 0.2495 - sparse_categorical_accuracy: 0.9059 - val_loss: 0.3248 - val_sparse_categorical_accuracy: 0.8294
# Epoch 42/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.2426 - sparse_categorical_accuracy: 0.9066 - val_loss: 0.3294 - val_sparse_categorical_accuracy: 0.8460
# Epoch 43/500
# 2880/2880 [==============================] - 1s 180us/sample - loss: 0.2467 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.2323 - val_sparse_categorical_accuracy: 0.9015
# Epoch 44/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.2484 - sparse_categorical_accuracy: 0.8993 - val_loss: 0.2572 - val_sparse_categorical_accuracy: 0.9015
# Epoch 45/500
# 2880/2880 [==============================] - 0s 169us/sample - loss: 0.2442 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.4088 - val_sparse_categorical_accuracy: 0.8128
# Epoch 46/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.2530 - sparse_categorical_accuracy: 0.8951 - val_loss: 0.2409 - val_sparse_categorical_accuracy: 0.9071
# Epoch 47/500
# 2880/2880 [==============================] - 0s 170us/sample - loss: 0.2429 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.2553 - val_sparse_categorical_accuracy: 0.8793
# Epoch 48/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.2381 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.7002 - val_sparse_categorical_accuracy: 0.6893
# Epoch 49/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.2297 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.3831 - val_sparse_categorical_accuracy: 0.8322
# Epoch 50/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.2332 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.2937 - val_sparse_categorical_accuracy: 0.8460
# Epoch 51/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.2753 - sparse_categorical_accuracy: 0.8806 - val_loss: 0.2530 - val_sparse_categorical_accuracy: 0.8932
# Epoch 52/500
# 2880/2880 [==============================] - 0s 169us/sample - loss: 0.2333 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.2542 - val_sparse_categorical_accuracy: 0.8710
# Epoch 53/500
# 2880/2880 [==============================] - 0s 169us/sample - loss: 0.2211 - sparse_categorical_accuracy: 0.9108 - val_loss: 0.2880 - val_sparse_categorical_accuracy: 0.8544
# Epoch 54/500
# 2880/2880 [==============================] - 1s 176us/sample - loss: 0.2151 - sparse_categorical_accuracy: 0.9135 - val_loss: 0.2774 - val_sparse_categorical_accuracy: 0.8696
# Epoch 55/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.2325 - sparse_categorical_accuracy: 0.9010 - val_loss: 0.2613 - val_sparse_categorical_accuracy: 0.8807
# Epoch 56/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.2291 - sparse_categorical_accuracy: 0.9066 - val_loss: 0.2770 - val_sparse_categorical_accuracy: 0.8585
# Epoch 57/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.2232 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.2636 - val_sparse_categorical_accuracy: 0.8710
# Epoch 58/500
# 2880/2880 [==============================] - 0s 159us/sample - loss: 0.2306 - sparse_categorical_accuracy: 0.9069 - val_loss: 0.3296 - val_sparse_categorical_accuracy: 0.8433
# Epoch 59/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.2076 - sparse_categorical_accuracy: 0.9149 - val_loss: 0.3725 - val_sparse_categorical_accuracy: 0.8266
# Epoch 60/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.2178 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.7669 - val_sparse_categorical_accuracy: 0.7074
# Epoch 61/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.2112 - sparse_categorical_accuracy: 0.9170 - val_loss: 0.2688 - val_sparse_categorical_accuracy: 0.8904
# Epoch 62/500
# 2880/2880 [==============================] - 0s 171us/sample - loss: 0.2055 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.2787 - val_sparse_categorical_accuracy: 0.8807
# Epoch 63/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.2080 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.3546 - val_sparse_categorical_accuracy: 0.8544
# Epoch 64/500
# 2880/2880 [==============================] - 1s 181us/sample - loss: 0.1956 - sparse_categorical_accuracy: 0.9250 - val_loss: 0.2160 - val_sparse_categorical_accuracy: 0.9168
# Epoch 65/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.1791 - sparse_categorical_accuracy: 0.9368 - val_loss: 0.2583 - val_sparse_categorical_accuracy: 0.8821
# Epoch 66/500
# 2880/2880 [==============================] - 1s 182us/sample - loss: 0.1751 - sparse_categorical_accuracy: 0.9399 - val_loss: 0.1927 - val_sparse_categorical_accuracy: 0.9320
# Epoch 67/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.1676 - sparse_categorical_accuracy: 0.9368 - val_loss: 0.2184 - val_sparse_categorical_accuracy: 0.8932
# Epoch 68/500
# 2880/2880 [==============================] - 1s 190us/sample - loss: 0.1640 - sparse_categorical_accuracy: 0.9403 - val_loss: 0.3811 - val_sparse_categorical_accuracy: 0.8044
# Epoch 69/500
# 2880/2880 [==============================] - 1s 210us/sample - loss: 0.1753 - sparse_categorical_accuracy: 0.9347 - val_loss: 0.1807 - val_sparse_categorical_accuracy: 0.9307
# Epoch 70/500
# 2880/2880 [==============================] - 1s 177us/sample - loss: 0.1576 - sparse_categorical_accuracy: 0.9469 - val_loss: 0.1826 - val_sparse_categorical_accuracy: 0.9307
# Epoch 71/500
# 2880/2880 [==============================] - 1s 182us/sample - loss: 0.1520 - sparse_categorical_accuracy: 0.9490 - val_loss: 0.1866 - val_sparse_categorical_accuracy: 0.9223
# Epoch 72/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.1532 - sparse_categorical_accuracy: 0.9451 - val_loss: 0.1939 - val_sparse_categorical_accuracy: 0.9237
# Epoch 73/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.1461 - sparse_categorical_accuracy: 0.9514 - val_loss: 0.2639 - val_sparse_categorical_accuracy: 0.8946
# Epoch 74/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.1436 - sparse_categorical_accuracy: 0.9493 - val_loss: 0.2004 - val_sparse_categorical_accuracy: 0.9168
# Epoch 75/500
# 2880/2880 [==============================] - 0s 170us/sample - loss: 0.1346 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.1828 - val_sparse_categorical_accuracy: 0.9196
# Epoch 76/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.1322 - sparse_categorical_accuracy: 0.9552 - val_loss: 0.1532 - val_sparse_categorical_accuracy: 0.9404
# Epoch 77/500
# 2880/2880 [==============================] - 1s 193us/sample - loss: 0.1338 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.1422 - val_sparse_categorical_accuracy: 0.9376
# Epoch 78/500
# 2880/2880 [==============================] - 1s 188us/sample - loss: 0.1307 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.1488 - val_sparse_categorical_accuracy: 0.9404
# Epoch 79/500
# 2880/2880 [==============================] - 0s 170us/sample - loss: 0.1354 - sparse_categorical_accuracy: 0.9514 - val_loss: 0.1603 - val_sparse_categorical_accuracy: 0.9362
# Epoch 80/500
# 2880/2880 [==============================] - 1s 175us/sample - loss: 0.1288 - sparse_categorical_accuracy: 0.9569 - val_loss: 0.1413 - val_sparse_categorical_accuracy: 0.9487
# Epoch 81/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.1206 - sparse_categorical_accuracy: 0.9590 - val_loss: 0.1972 - val_sparse_categorical_accuracy: 0.9209
# Epoch 82/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.1269 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.1992 - val_sparse_categorical_accuracy: 0.9071
# Epoch 83/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.1221 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.2265 - val_sparse_categorical_accuracy: 0.9071
# Epoch 84/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.1154 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.1420 - val_sparse_categorical_accuracy: 0.9515
# Epoch 85/500
# 2880/2880 [==============================] - 1s 186us/sample - loss: 0.1177 - sparse_categorical_accuracy: 0.9590 - val_loss: 0.2152 - val_sparse_categorical_accuracy: 0.9112
# Epoch 86/500
# 2880/2880 [==============================] - 1s 184us/sample - loss: 0.1233 - sparse_categorical_accuracy: 0.9590 - val_loss: 0.1535 - val_sparse_categorical_accuracy: 0.9348
# Epoch 87/500
# 2880/2880 [==============================] - 1s 180us/sample - loss: 0.1099 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.1200 - val_sparse_categorical_accuracy: 0.9528
# Epoch 88/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.1103 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.1202 - val_sparse_categorical_accuracy: 0.9528
# Epoch 89/500
# 2880/2880 [==============================] - 0s 170us/sample - loss: 0.1112 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.1352 - val_sparse_categorical_accuracy: 0.9473
# Epoch 90/500
# 2880/2880 [==============================] - 0s 173us/sample - loss: 0.1112 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1215 - val_sparse_categorical_accuracy: 0.9528
# Epoch 91/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.1106 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1551 - val_sparse_categorical_accuracy: 0.9487
# Epoch 92/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.1066 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.1256 - val_sparse_categorical_accuracy: 0.9570
# Epoch 93/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.1123 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1207 - val_sparse_categorical_accuracy: 0.9515
# Epoch 94/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.1170 - sparse_categorical_accuracy: 0.9583 - val_loss: 0.1473 - val_sparse_categorical_accuracy: 0.9431
# Epoch 95/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.1048 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.1064 - val_sparse_categorical_accuracy: 0.9639
# Epoch 96/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.1106 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.1737 - val_sparse_categorical_accuracy: 0.9237
# Epoch 97/500
# 2880/2880 [==============================] - 0s 159us/sample - loss: 0.0974 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.1738 - val_sparse_categorical_accuracy: 0.9431
# Epoch 98/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.1015 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.1066 - val_sparse_categorical_accuracy: 0.9612
# Epoch 99/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.1017 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1834 - val_sparse_categorical_accuracy: 0.9209
# Epoch 100/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.1037 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.1323 - val_sparse_categorical_accuracy: 0.9528
# Epoch 101/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.1022 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.1446 - val_sparse_categorical_accuracy: 0.9445
# Epoch 102/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.1096 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1473 - val_sparse_categorical_accuracy: 0.9431
# Epoch 103/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0998 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.1068 - val_sparse_categorical_accuracy: 0.9612
# Epoch 104/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.1017 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.1198 - val_sparse_categorical_accuracy: 0.9528
# Epoch 105/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0960 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1076 - val_sparse_categorical_accuracy: 0.9612
# Epoch 106/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0956 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.1106 - val_sparse_categorical_accuracy: 0.9681
# Epoch 107/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0946 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.1939 - val_sparse_categorical_accuracy: 0.9237
# Epoch 108/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0987 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1491 - val_sparse_categorical_accuracy: 0.9515
# Epoch 109/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0938 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.1319 - val_sparse_categorical_accuracy: 0.9542
# Epoch 110/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0979 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.1646 - val_sparse_categorical_accuracy: 0.9417
# Epoch 111/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0941 - sparse_categorical_accuracy: 0.9656 - val_loss: 0.1267 - val_sparse_categorical_accuracy: 0.9570
# Epoch 112/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.1009 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.1077 - val_sparse_categorical_accuracy: 0.9667
# Epoch 113/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0931 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.3250 - val_sparse_categorical_accuracy: 0.8669
# Epoch 114/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0958 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.1125 - val_sparse_categorical_accuracy: 0.9598
# Epoch 115/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0932 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.1292 - val_sparse_categorical_accuracy: 0.9473
# Epoch 116/500
# 2880/2880 [==============================] - 0s 172us/sample - loss: 0.0861 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.1034 - val_sparse_categorical_accuracy: 0.9584
# Epoch 117/500
# 2880/2880 [==============================] - 1s 180us/sample - loss: 0.0925 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.0981 - val_sparse_categorical_accuracy: 0.9681
# Epoch 118/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0817 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1012 - val_sparse_categorical_accuracy: 0.9695
# Epoch 119/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0833 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.1001 - val_sparse_categorical_accuracy: 0.9667
# Epoch 120/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0893 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.0989 - val_sparse_categorical_accuracy: 0.9681
# Epoch 121/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0837 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.1032 - val_sparse_categorical_accuracy: 0.9667
# Epoch 122/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0846 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.1141 - val_sparse_categorical_accuracy: 0.9528
# Epoch 123/500
# 2880/2880 [==============================] - 0s 159us/sample - loss: 0.0820 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.0996 - val_sparse_categorical_accuracy: 0.9584
# Epoch 124/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0800 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.0984 - val_sparse_categorical_accuracy: 0.9626
# Epoch 125/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0877 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.1138 - val_sparse_categorical_accuracy: 0.9667
# Epoch 126/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0901 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1016 - val_sparse_categorical_accuracy: 0.9612
# Epoch 127/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0865 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.1193 - val_sparse_categorical_accuracy: 0.9528
# Epoch 128/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0869 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.1094 - val_sparse_categorical_accuracy: 0.9570
# Epoch 129/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0835 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.0991 - val_sparse_categorical_accuracy: 0.9584
# Epoch 130/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0861 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1069 - val_sparse_categorical_accuracy: 0.9598
# Epoch 131/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0805 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1010 - val_sparse_categorical_accuracy: 0.9681
# Epoch 132/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0770 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0986 - val_sparse_categorical_accuracy: 0.9653
# Epoch 133/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0833 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.1000 - val_sparse_categorical_accuracy: 0.9612
# Epoch 134/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0846 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1124 - val_sparse_categorical_accuracy: 0.9653
# Epoch 135/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0824 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.1096 - val_sparse_categorical_accuracy: 0.9584
# Epoch 136/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0862 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.1032 - val_sparse_categorical_accuracy: 0.9667
# Epoch 137/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0846 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.1289 - val_sparse_categorical_accuracy: 0.9570
# Epoch 138/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0804 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1039 - val_sparse_categorical_accuracy: 0.9639
# Epoch 139/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0778 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.0982 - val_sparse_categorical_accuracy: 0.9667
# Epoch 140/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0753 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0986 - val_sparse_categorical_accuracy: 0.9612
# Epoch 141/500
# 2880/2880 [==============================] - 1s 175us/sample - loss: 0.0774 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0975 - val_sparse_categorical_accuracy: 0.9681
# Epoch 142/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0814 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1152 - val_sparse_categorical_accuracy: 0.9612
# Epoch 143/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0814 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1001 - val_sparse_categorical_accuracy: 0.9653
# Epoch 144/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0782 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1012 - val_sparse_categorical_accuracy: 0.9653
# Epoch 145/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0762 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0986 - val_sparse_categorical_accuracy: 0.9598
# Epoch 146/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.0760 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.0959 - val_sparse_categorical_accuracy: 0.9639
# Epoch 147/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0730 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1066 - val_sparse_categorical_accuracy: 0.9542
# Epoch 148/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0807 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1048 - val_sparse_categorical_accuracy: 0.9653
# Epoch 149/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0758 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1072 - val_sparse_categorical_accuracy: 0.9667
# Epoch 150/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0710 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1008 - val_sparse_categorical_accuracy: 0.9667
# Epoch 151/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0772 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1031 - val_sparse_categorical_accuracy: 0.9653
# Epoch 152/500
# 2880/2880 [==============================] - 0s 169us/sample - loss: 0.0797 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0961 - val_sparse_categorical_accuracy: 0.9681
# Epoch 153/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0806 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1057 - val_sparse_categorical_accuracy: 0.9626
# Epoch 154/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0756 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.1054 - val_sparse_categorical_accuracy: 0.9653
# Epoch 155/500
# 2880/2880 [==============================] - 0s 169us/sample - loss: 0.0738 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0969 - val_sparse_categorical_accuracy: 0.9709
# Epoch 156/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0745 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1009 - val_sparse_categorical_accuracy: 0.9667
# Epoch 157/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0818 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1041 - val_sparse_categorical_accuracy: 0.9639
# Epoch 158/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0728 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0973 - val_sparse_categorical_accuracy: 0.9681
# Epoch 159/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0771 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.1034 - val_sparse_categorical_accuracy: 0.9626
# Epoch 160/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0736 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1011 - val_sparse_categorical_accuracy: 0.9653
# Epoch 161/500
# 2880/2880 [==============================] - 0s 159us/sample - loss: 0.0748 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1062 - val_sparse_categorical_accuracy: 0.9653
# Epoch 162/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0733 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.1121 - val_sparse_categorical_accuracy: 0.9612
# Epoch 163/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0770 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.0960 - val_sparse_categorical_accuracy: 0.9639
# Epoch 164/500
# 2880/2880 [==============================] - 0s 173us/sample - loss: 0.0816 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.0957 - val_sparse_categorical_accuracy: 0.9695
# Epoch 165/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.0745 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.0954 - val_sparse_categorical_accuracy: 0.9653
# Epoch 166/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0713 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.0965 - val_sparse_categorical_accuracy: 0.9695
# Epoch 167/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0764 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0974 - val_sparse_categorical_accuracy: 0.9695
# Epoch 168/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0759 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0963 - val_sparse_categorical_accuracy: 0.9681
# Epoch 169/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0750 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0994 - val_sparse_categorical_accuracy: 0.9667
# Epoch 170/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0739 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.0958 - val_sparse_categorical_accuracy: 0.9653
# Epoch 171/500
# 2880/2880 [==============================] - 0s 160us/sample - loss: 0.0719 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1008 - val_sparse_categorical_accuracy: 0.9681
# Epoch 172/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0733 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.0956 - val_sparse_categorical_accuracy: 0.9695
# Epoch 173/500
# 2880/2880 [==============================] - 0s 160us/sample - loss: 0.0754 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.0961 - val_sparse_categorical_accuracy: 0.9626
# Epoch 174/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0692 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.1008 - val_sparse_categorical_accuracy: 0.9653
# Epoch 175/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0736 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1029 - val_sparse_categorical_accuracy: 0.9667
# Epoch 176/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0765 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1179 - val_sparse_categorical_accuracy: 0.9570
# Epoch 177/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0741 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.1006 - val_sparse_categorical_accuracy: 0.9695
# Epoch 178/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0742 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.1079 - val_sparse_categorical_accuracy: 0.9626
# Epoch 179/500
# 2880/2880 [==============================] - 0s 173us/sample - loss: 0.0729 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0934 - val_sparse_categorical_accuracy: 0.9639
# Epoch 180/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0753 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1008 - val_sparse_categorical_accuracy: 0.9653
# Epoch 181/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0705 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.0947 - val_sparse_categorical_accuracy: 0.9695
# Epoch 182/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0705 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1002 - val_sparse_categorical_accuracy: 0.9612
# Epoch 183/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0746 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.1000 - val_sparse_categorical_accuracy: 0.9681
# Epoch 184/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0763 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.0998 - val_sparse_categorical_accuracy: 0.9695
# Epoch 185/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0752 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1056 - val_sparse_categorical_accuracy: 0.9639
# Epoch 186/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0721 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.0946 - val_sparse_categorical_accuracy: 0.9667
# Epoch 187/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0706 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0964 - val_sparse_categorical_accuracy: 0.9639
# Epoch 188/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0744 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0985 - val_sparse_categorical_accuracy: 0.9639
# Epoch 189/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0740 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.0956 - val_sparse_categorical_accuracy: 0.9626
# Epoch 190/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.0710 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9695
# Epoch 191/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0715 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.1023 - val_sparse_categorical_accuracy: 0.9667
# Epoch 192/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0719 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0986 - val_sparse_categorical_accuracy: 0.9667
# Epoch 193/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0707 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1135 - val_sparse_categorical_accuracy: 0.9584
# Epoch 194/500
# 2880/2880 [==============================] - 0s 170us/sample - loss: 0.0683 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0944 - val_sparse_categorical_accuracy: 0.9626
# Epoch 195/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0721 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.0928 - val_sparse_categorical_accuracy: 0.9695
# Epoch 196/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0692 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.0951 - val_sparse_categorical_accuracy: 0.9709
# Epoch 197/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0763 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0951 - val_sparse_categorical_accuracy: 0.9695
# Epoch 198/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0703 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0942 - val_sparse_categorical_accuracy: 0.9653
# Epoch 199/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0718 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.0927 - val_sparse_categorical_accuracy: 0.9653
# Epoch 200/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0733 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0963 - val_sparse_categorical_accuracy: 0.9681
# Epoch 201/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0729 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1094 - val_sparse_categorical_accuracy: 0.9626
# Epoch 202/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0729 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.0957 - val_sparse_categorical_accuracy: 0.9681
# Epoch 203/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0696 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0946 - val_sparse_categorical_accuracy: 0.9681
# Epoch 204/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0668 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1018 - val_sparse_categorical_accuracy: 0.9626
# Epoch 205/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0721 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0946 - val_sparse_categorical_accuracy: 0.9681
# Epoch 206/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0688 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0947 - val_sparse_categorical_accuracy: 0.9681
# Epoch 207/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0682 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0948 - val_sparse_categorical_accuracy: 0.9653
# Epoch 208/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0711 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0967 - val_sparse_categorical_accuracy: 0.9667
# Epoch 209/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0690 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0987 - val_sparse_categorical_accuracy: 0.9653
# Epoch 210/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0621 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0965 - val_sparse_categorical_accuracy: 0.9626
# Epoch 211/500
# 2880/2880 [==============================] - 0s 160us/sample - loss: 0.0712 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.1085 - val_sparse_categorical_accuracy: 0.9598
# Epoch 212/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0737 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0957 - val_sparse_categorical_accuracy: 0.9667
# Epoch 213/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0716 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0940 - val_sparse_categorical_accuracy: 0.9667
# Epoch 214/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0689 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1028 - val_sparse_categorical_accuracy: 0.9612
# Epoch 215/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0694 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1206 - val_sparse_categorical_accuracy: 0.9487
# Epoch 216/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0716 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1104 - val_sparse_categorical_accuracy: 0.9556
# Epoch 217/500
# 2880/2880 [==============================] - 1s 178us/sample - loss: 0.0677 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.0911 - val_sparse_categorical_accuracy: 0.9695
# Epoch 218/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0690 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.0969 - val_sparse_categorical_accuracy: 0.9681
# Epoch 219/500
# 2880/2880 [==============================] - 0s 171us/sample - loss: 0.0706 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0977 - val_sparse_categorical_accuracy: 0.9570
# Epoch 220/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0699 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.0975 - val_sparse_categorical_accuracy: 0.9653
# Epoch 221/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0682 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0923 - val_sparse_categorical_accuracy: 0.9667
# Epoch 222/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0725 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.1074 - val_sparse_categorical_accuracy: 0.9612
# Epoch 223/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0693 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.1136 - val_sparse_categorical_accuracy: 0.9515
# Epoch 224/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0736 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1004 - val_sparse_categorical_accuracy: 0.9639
# Epoch 225/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0644 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.0948 - val_sparse_categorical_accuracy: 0.9667
# Epoch 226/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0674 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.0960 - val_sparse_categorical_accuracy: 0.9709
# Epoch 227/500
# 2880/2880 [==============================] - 0s 158us/sample - loss: 0.0689 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1002 - val_sparse_categorical_accuracy: 0.9653
# Epoch 228/500
# 2880/2880 [==============================] - 0s 160us/sample - loss: 0.0733 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.0952 - val_sparse_categorical_accuracy: 0.9695
# Epoch 229/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0711 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0943 - val_sparse_categorical_accuracy: 0.9653
# Epoch 230/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0692 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1143 - val_sparse_categorical_accuracy: 0.9612
# Epoch 231/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0699 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.1003 - val_sparse_categorical_accuracy: 0.9598
# Epoch 232/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0684 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0948 - val_sparse_categorical_accuracy: 0.9681
# Epoch 233/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0704 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0976 - val_sparse_categorical_accuracy: 0.9695
# Epoch 234/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0671 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1059 - val_sparse_categorical_accuracy: 0.9639
# Epoch 235/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0657 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1000 - val_sparse_categorical_accuracy: 0.9584
# Epoch 236/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0661 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.0930 - val_sparse_categorical_accuracy: 0.9681
# Epoch 237/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0709 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0931 - val_sparse_categorical_accuracy: 0.9653
# Epoch 238/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0690 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0940 - val_sparse_categorical_accuracy: 0.9667
# Epoch 239/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0636 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.0938 - val_sparse_categorical_accuracy: 0.9653
# Epoch 240/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0632 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.0959 - val_sparse_categorical_accuracy: 0.9695
# Epoch 241/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0695 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1184 - val_sparse_categorical_accuracy: 0.9626
# Epoch 242/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0675 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1031 - val_sparse_categorical_accuracy: 0.9570
# Epoch 243/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0723 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0932 - val_sparse_categorical_accuracy: 0.9626
# Epoch 244/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0599 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.0965 - val_sparse_categorical_accuracy: 0.9667
# Epoch 245/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0682 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.0949 - val_sparse_categorical_accuracy: 0.9681
# Epoch 246/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0646 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.0925 - val_sparse_categorical_accuracy: 0.9653
# Epoch 247/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0652 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1049 - val_sparse_categorical_accuracy: 0.9626
# Epoch 248/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0676 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.0934 - val_sparse_categorical_accuracy: 0.9695
# Epoch 249/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0662 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.0974 - val_sparse_categorical_accuracy: 0.9695
# Epoch 250/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0665 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.1030 - val_sparse_categorical_accuracy: 0.9515
# Epoch 251/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0655 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.0928 - val_sparse_categorical_accuracy: 0.9667
# Epoch 252/500
# 2880/2880 [==============================] - 0s 169us/sample - loss: 0.0673 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0985 - val_sparse_categorical_accuracy: 0.9653
# Epoch 253/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0670 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1114 - val_sparse_categorical_accuracy: 0.9639
# Epoch 254/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0641 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0937 - val_sparse_categorical_accuracy: 0.9681
# Epoch 255/500
# 2880/2880 [==============================] - 1s 181us/sample - loss: 0.0689 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0911 - val_sparse_categorical_accuracy: 0.9667
# Epoch 256/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0656 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0959 - val_sparse_categorical_accuracy: 0.9681
# Epoch 257/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0615 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.1041 - val_sparse_categorical_accuracy: 0.9626
# Epoch 258/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0668 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1018 - val_sparse_categorical_accuracy: 0.9598
# Epoch 259/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0641 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1059 - val_sparse_categorical_accuracy: 0.9598
# Epoch 260/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0651 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0920 - val_sparse_categorical_accuracy: 0.9695
# Epoch 261/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0683 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0984 - val_sparse_categorical_accuracy: 0.9653
# Epoch 262/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0659 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0922 - val_sparse_categorical_accuracy: 0.9736
# Epoch 263/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0668 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0988 - val_sparse_categorical_accuracy: 0.9667
# Epoch 264/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0642 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1108 - val_sparse_categorical_accuracy: 0.9612
# Epoch 265/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0656 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.1021 - val_sparse_categorical_accuracy: 0.9542
# Epoch 266/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0605 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0954 - val_sparse_categorical_accuracy: 0.9681
# Epoch 267/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0673 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0954 - val_sparse_categorical_accuracy: 0.9695
# Epoch 268/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0643 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0990 - val_sparse_categorical_accuracy: 0.9695
# Epoch 269/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0606 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.1031 - val_sparse_categorical_accuracy: 0.9653
# Epoch 270/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0668 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0914 - val_sparse_categorical_accuracy: 0.9653
# Epoch 271/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0640 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1096 - val_sparse_categorical_accuracy: 0.9570
# Epoch 272/500
# 2880/2880 [==============================] - 0s 169us/sample - loss: 0.0645 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1005 - val_sparse_categorical_accuracy: 0.9667
# Epoch 273/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0665 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1007 - val_sparse_categorical_accuracy: 0.9653
# Epoch 274/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0701 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1113 - val_sparse_categorical_accuracy: 0.9612
# Epoch 275/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0629 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.0938 - val_sparse_categorical_accuracy: 0.9667
# Epoch 276/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0662 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1076 - val_sparse_categorical_accuracy: 0.9515
# Epoch 277/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0681 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1138 - val_sparse_categorical_accuracy: 0.9501
# Epoch 278/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0604 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.1020 - val_sparse_categorical_accuracy: 0.9639
# Epoch 279/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0648 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1008 - val_sparse_categorical_accuracy: 0.9681
# Epoch 280/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0654 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.1547 - val_sparse_categorical_accuracy: 0.9487
# Epoch 281/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0691 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.0942 - val_sparse_categorical_accuracy: 0.9667
# Epoch 282/500
# 2880/2880 [==============================] - 1s 174us/sample - loss: 0.0594 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0904 - val_sparse_categorical_accuracy: 0.9681
# Epoch 283/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0611 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0951 - val_sparse_categorical_accuracy: 0.9709
# Epoch 284/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0679 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.0941 - val_sparse_categorical_accuracy: 0.9667
# Epoch 285/500
# 2880/2880 [==============================] - 0s 160us/sample - loss: 0.0658 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0915 - val_sparse_categorical_accuracy: 0.9653
# Epoch 286/500
# 2880/2880 [==============================] - 0s 172us/sample - loss: 0.0639 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.0957 - val_sparse_categorical_accuracy: 0.9695
# Epoch 287/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0653 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.0941 - val_sparse_categorical_accuracy: 0.9653
# Epoch 288/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0614 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.1269 - val_sparse_categorical_accuracy: 0.9556
# Epoch 289/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0682 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1048 - val_sparse_categorical_accuracy: 0.9584
# Epoch 290/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0641 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0945 - val_sparse_categorical_accuracy: 0.9695
# Epoch 291/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0624 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0916 - val_sparse_categorical_accuracy: 0.9653
# Epoch 292/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0668 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0916 - val_sparse_categorical_accuracy: 0.9695
# Epoch 293/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0638 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0927 - val_sparse_categorical_accuracy: 0.9667
# Epoch 294/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0672 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.0951 - val_sparse_categorical_accuracy: 0.9653
# Epoch 295/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0700 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.1047 - val_sparse_categorical_accuracy: 0.9667
# Epoch 296/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0689 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0930 - val_sparse_categorical_accuracy: 0.9695
# Epoch 297/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0674 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0914 - val_sparse_categorical_accuracy: 0.9709
# Epoch 298/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0638 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.0943 - val_sparse_categorical_accuracy: 0.9695
# Epoch 299/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0676 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0915 - val_sparse_categorical_accuracy: 0.9639
# Epoch 300/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0641 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.0952 - val_sparse_categorical_accuracy: 0.9667
# Epoch 301/500
# 2880/2880 [==============================] - 0s 165us/sample - loss: 0.0645 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0929 - val_sparse_categorical_accuracy: 0.9681
# Epoch 302/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0677 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0935 - val_sparse_categorical_accuracy: 0.9653
# Epoch 303/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0605 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.1015 - val_sparse_categorical_accuracy: 0.9653
# Epoch 304/500
# 2880/2880 [==============================] - 0s 160us/sample - loss: 0.0608 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0960 - val_sparse_categorical_accuracy: 0.9612
# Epoch 305/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0614 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.1108 - val_sparse_categorical_accuracy: 0.9528
# Epoch 306/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0631 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.1097 - val_sparse_categorical_accuracy: 0.9542
# Epoch 307/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0636 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0916 - val_sparse_categorical_accuracy: 0.9667
# Epoch 308/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0625 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.1105 - val_sparse_categorical_accuracy: 0.9612
# Epoch 309/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0591 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0959 - val_sparse_categorical_accuracy: 0.9681
# Epoch 310/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0629 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0961 - val_sparse_categorical_accuracy: 0.9695
# Epoch 311/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0652 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.0974 - val_sparse_categorical_accuracy: 0.9667
# Epoch 312/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0678 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0905 - val_sparse_categorical_accuracy: 0.9681
# Epoch 313/500
# 2880/2880 [==============================] - 0s 163us/sample - loss: 0.0653 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.0937 - val_sparse_categorical_accuracy: 0.9681
# Epoch 314/500
# 2880/2880 [==============================] - 0s 160us/sample - loss: 0.0621 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.1087 - val_sparse_categorical_accuracy: 0.9667
# Epoch 315/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0635 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0978 - val_sparse_categorical_accuracy: 0.9695
# Epoch 316/500
# 2880/2880 [==============================] - 0s 162us/sample - loss: 0.0596 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.0929 - val_sparse_categorical_accuracy: 0.9653
# Epoch 317/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0640 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1433 - val_sparse_categorical_accuracy: 0.9542
# Epoch 318/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0625 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9709
# Epoch 319/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0633 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.0970 - val_sparse_categorical_accuracy: 0.9695
# Epoch 320/500
# 2880/2880 [==============================] - 0s 168us/sample - loss: 0.0596 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0940 - val_sparse_categorical_accuracy: 0.9695
# Epoch 321/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0618 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.1136 - val_sparse_categorical_accuracy: 0.9570
# Epoch 322/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0600 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0927 - val_sparse_categorical_accuracy: 0.9667
# Epoch 323/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0555 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.1003 - val_sparse_categorical_accuracy: 0.9626
# Epoch 324/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0618 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.1109 - val_sparse_categorical_accuracy: 0.9556
# Epoch 325/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0554 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0934 - val_sparse_categorical_accuracy: 0.9681
# Epoch 326/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0591 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.0981 - val_sparse_categorical_accuracy: 0.9681
# Epoch 327/500
# 2880/2880 [==============================] - 0s 169us/sample - loss: 0.0658 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1128 - val_sparse_categorical_accuracy: 0.9515
# Epoch 328/500
# 2880/2880 [==============================] - 0s 164us/sample - loss: 0.0611 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1106 - val_sparse_categorical_accuracy: 0.9584
# Epoch 329/500
# 2880/2880 [==============================] - 0s 167us/sample - loss: 0.0649 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1083 - val_sparse_categorical_accuracy: 0.9626
# Epoch 330/500
# 2880/2880 [==============================] - 0s 160us/sample - loss: 0.0592 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0936 - val_sparse_categorical_accuracy: 0.9667
# Epoch 331/500
# 2880/2880 [==============================] - 0s 166us/sample - loss: 0.0621 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0961 - val_sparse_categorical_accuracy: 0.9695
# Epoch 332/500
# 2880/2880 [==============================] - 0s 161us/sample - loss: 0.0607 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.0949 - val_sparse_categorical_accuracy: 0.9681
# Epoch 00332: early stopping

# %% [markdown]
# ## Das Modell auf den Testdaten evaluieren

# %% [markdown]
# Bug: Manchmal wird doppelt gelogged

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

log.info('[Normal Test] Accuracy: {} durch die Hyperparameter -> {}'.format(float(test_acc), hyper_p))

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 1320/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Test accuracy 0.969697
# Test loss 0.09464872881318584

# %% [markdown]
# ## Train- und Validation-Loss des Modells plotten

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %% [markdown]
# ##  Exportieren der besten Hyperparameter
# Diese Funktion exportiert die Hyperparameter als JSON Datei wenn die aktuelle Test-Accuracy besser ist als die vorherige

# %%
def save():
    hyper_para = {
                "acc" : float(test_acc)
                }
    hyper_para.update(hyper_p)
    path = './'
    file_name = 'hyperparameter'
    write_JSON_file(path, file_name, hyper_para)
    
# wenn best_acc noch nicht definiert ist => importieren von der besten Einstellung sonst 0
try:
    best_acc
except NameError:
    try:
        param = load_JSON("./hyperparameter.json")
        if param:
            best_acc = param["acc"] if "acc" in param else 0
    except FileNotFoundError:
        best_acc = 0

if best_acc < test_acc:
    save()
    print("Die Test Accuracy: {} ist besser als die vorherige Accuracy: {}. Die Datei wurde gespeichtert.".format(test_acc, best_acc))
    best_acc = test_acc
else:
    print("Die aktuellen Tests waren nicht besser als der vorherige beste Run. Aktuell:{}, Beste:{}".format(test_acc, best_acc))
# Out:
# Die Test Accuracy: 0.9696969985961914 ist besser als die vorherige Accuracy: 0.9371212124824524. Die Datei wurde gespeichtert.
